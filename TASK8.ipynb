# %% [markdown]
# #  Import Liberaries

# %%
import pandas as pd

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv("superstore_sales.csv", encoding="latin1")

# %%
df.head(10)
# Out:
#    order_date     customer_name      country   region         category sales  \
# 0  01-01-2011   Toby Braunhardt      Algeria   Africa  Office Supplies   408
# 1  01-01-2011       Joseph Holt    Australia  Oceania  Office Supplies   120
# 2  01-01-2011     Annie Thurman      Hungary     EMEA  Office Supplies    66
# 3  01-01-2011      Eugene Moren       Sweden    North  Office Supplies    45
# 4  01-01-2011       Joseph Holt    Australia  Oceania        Furniture   114
# 5  01-01-2011       Joseph Holt    Australia  Oceania  Office Supplies    55
# 6  02-01-2011   Magdelene Morse       Canada   Canada       Technology   314
# 7  03-01-2011       Kean Nguyen    Australia  Oceania  Office Supplies   276
# 8  03-01-2011      Ken Lonsdale  New Zealand  Oceania       Technology   912
# 9  03-01-2011  Lindsay Williams         Iraq     EMEA        Furniture   667
#
#     profit
# 0  106.140
# 1   36.036
# 2   29.640
# 3  -26.055
# 4   37.770
# 5   15.342
# 6    3.120
# 7  110.412
# 8 -319.464
# 9  253.320

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['order_date', 'customer_name', 'country', 'region', 'category', 'sales',
#        'profit'],
#       dtype='object')

# %%
df.size
# Out:
# 359030

# %%
df.index
# Out:
# RangeIndex(start=0, stop=51290, step=1)

# %% [markdown]
# #  Information about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_date     51290 non-null  object
#  1   customer_name  51290 non-null  object
#  2   country        51290 non-null  object
#  3   region         51290 non-null  object
#  4   category       51290 non-null  object
#  5   sales          51290 non-null  object
#  6   profit         51290 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 2.7+ MB

# %%
df.describe()
# Out:
#              profit
# count  51290.000000
# mean      28.641740
# std      174.424113
# min    -6599.978000
# 25%        0.000000
# 50%        9.240000
# 75%       36.810000
# max     8399.976000

# %%
df.describe(include = object)
# Out:
#         order_date    customer_name        country   region         category  \
# count        51290            51290          51290    51290            51290
# unique        1430              795            147       13                3
# top     18-06-2014  Muhammed Yedwab  United States  Central  Office Supplies
# freq           135              108           9994    11117            31273
#
#         sales
# count   51290
# unique   2246
# top        13
# freq      589

# %%
df.describe(include = "number")
# Out:
#              profit
# count  51290.000000
# mean      28.641740
# std      174.424113
# min    -6599.978000
# 25%        0.000000
# 50%        9.240000
# 75%       36.810000
# max     8399.976000

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ###  Duplicate value

# %%
 df.duplicated().sum()
# Out:
# np.int64(11)

# %% [markdown]
# ###  Drop Duplicate Row

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
#  # Check Data-type

# %%
df.dtypes
# Out:
# order_date        object
# customer_name     object
# country           object
# region            object
# category          object
# sales             object
# profit           float64
# dtype: object

# %% [markdown]
# # Covert Data-type (fixing data type)

# %%
df['sales'] = pd.to_numeric(df['sales'], errors='coerce')

# %%
df.dtypes
# Out:
# order_date        object
# customer_name     object
# country           object
# region            object
# category          object
# sales            float64
# profit           float64
# dtype: object

# %%
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# %%
df.dtypes
# Out:
# order_date       datetime64[ns]
# customer_name            object
# country                  object
# region                   object
# category                 object
# sales                   float64
# profit                  float64
# dtype: object

# %% [markdown]
# #  Convert Order Date to “Month-Year” format

# %%
# Columns to convert
cols_to_format = ['customer_name', 'country', 'region', 'category']

# Convert to title case
for col in cols_to_format:
    df[col] = df[col].astype(str).str.strip().str.title()

# Convert order_date to datetime first
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# Convert to DD/MM/YYYY format
df['order_date'] = df['order_date'].dt.strftime('%d/%m/%Y')

# Create month_year column (format: Jan-2011)
df['month_year'] = pd.to_datetime(df['order_date'], format='%d/%m/%Y').dt.strftime('%b-%Y')

# %%
df.head(5127)
# Out:
#       order_date    customer_name        country   region         category  \
# 0     01/01/2011  Toby Braunhardt        Algeria   Africa  Office Supplies
# 1     01/01/2011      Joseph Holt      Australia  Oceania  Office Supplies
# 2     01/01/2011    Annie Thurman        Hungary     Emea  Office Supplies
# 3     01/01/2011     Eugene Moren         Sweden    North  Office Supplies
# 4     01/01/2011      Joseph Holt      Australia  Oceania        Furniture
# ...          ...              ...            ...      ...              ...
# 5124  12/09/2011     Rob Williams        Ireland    North  Office Supplies
# 5125  12/09/2011        Ann Chong      Guatemala  Central       Technology
# 5126  12/09/2011         Jim Sink      Nicaragua  Central       Technology
# 5127  12/09/2011      John Huston    El Salvador  Central       Technology
# 5128  12/09/2011       Art Foster  United States     East  Office Supplies
#
#       sales     profit month_year
# 0     408.0  106.14000   Jan-2011
# 1     120.0   36.03600   Jan-2011
# 2      66.0   29.64000   Jan-2011
# 3      45.0  -26.05500   Jan-2011
# 4     114.0   37.77000   Jan-2011
# ...     ...        ...        ...
# 5124   60.0  -37.20000   Sep-2011
# 5125  173.0   72.57268   Sep-2011
# 5126   97.0   39.80000   Sep-2011
# 5127  109.0   42.32000   Sep-2011
# 5128   64.0  -46.87760   Sep-2011
#
# [5127 rows x 8 columns]

# %% [markdown]
# # Clean data save

# %%
df.to_csv("superstore_sale_clean.csv", index=False)
